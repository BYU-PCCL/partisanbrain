# %%
import numpy as np
import string
import pandas as pd

# %%
from datasets import load_dataset
dataset = load_dataset("wiki_split")
# Out:
# Downloading builder script: 4.05kB [00:00, 1.05MB/s]
# Downloading metadata: 2.32kB [00:00, 1.07MB/s]
# Using custom data configuration default
# Downloading and preparing dataset wiki_split/default (download: 95.63 MiB, generated: 370.41 MiB, post-processed: Unknown size, total: 466.04 MiB) to /Users/alexshaw/.cache/huggingface/datasets/wiki_split/default/0.1.0/83151e5f3f5a622601303c2f562ffda5502643e38f3f1fee48999d0030f82b07...
# Downloading data: 100%|██████████| 96.4M/96.4M [00:11<00:00, 8.43MB/s]
# Downloading data: 1.93MB [00:00, 20.1MB/s]                  5.40s/it]
# Downloading data: 1.91MB [00:00, 18.1MB/s]/3 [00:17<00:07,  7.66s/it]
# Downloading data files: 100%|██████████| 3/3 [00:19<00:00,  6.44s/it]
# Extracting data files: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# Dataset wiki_split downloaded and prepared to /Users/alexshaw/.cache/huggingface/datasets/wiki_split/default/0.1.0/83151e5f3f5a622601303c2f562ffda5502643e38f3f1fee48999d0030f82b07. Subsequent calls will reuse this data.
# 100%|██████████| 3/3 [00:00<00:00, 59.23it/s]

# %%
def process_sentence(sentence):
    sentence = sentence.strip()
    punctuation = list(string.punctuation)
    for punc in punctuation:
        sentence = sentence.replace(f" {punc}", punc)
    sentence = sentence.replace("''", "")

    return sentence

# %%
simple_sentences = dataset['test']['simple_sentence_2']
simple_sentences = list(map(
    process_sentence,
    simple_sentences,
))

# %%
simple_sentences
# Out:
# ["It tells the story of the making of Bandolier in the band's own words, including an extensive audio interview with Burke Shelley.",
#  'Under his conditions it produces pitchers that are almost completley black.',
#  "Given that they're pulling out all the stops, they deserve all the acclaim that surrounded them for their first two albums.",
#  'It was their second EP and, like their first EP, was released only in Australia.',
#  'Contains a detailed monograph on Schisandra chinensis as well as highlights health benefits.',
#  'It is a instrumental particularly well- known for its robotic guitar solo.',
#  'After Ray Lynch and other artists left, the company was foreclosed by Security Pacific Bank on November 1991 with all of its assets sold by June 1992.',
#  'Nothing for his true grandmothers.',
#  'Hellbringer was a reference to his unquenchable thirst for debauchery and outlandish clothing.',
#  'This temple is one of the rare temples for worshiping Narasimha avathara of lord Vishnu.',
#  'One of those songs is the fifth track from the album Five Leaves Left by the British folk musician Nick Drake.',
#  'It was released in 1989 and written by fellow N.W.A group mate, MC Ren.',
#  'It was released on March 26, 2008.',
#  'It was released to radio on November 11, 2002.',
#  'Their music is also featured in The Crow salvation soundtrack, with the track I Know What You Want.',
#  'It peaked at number 10 on the Easy Listening chart.',
#  'James recorded and released his version the following year with his band the Shondells as part of their album Crimson and Clover.',
#  'The most popular version was done by Patti Page in 1950.',
#  'It is notable as the debut of the then teenage Brightman as a singer.',
#  'It originally aired on the Fox network in the United States on November 26, 2006.',
#  'It sets out priorities for scientists to work with Indigenous communities to help them manage their lands themselves.',
#  'It was originally released by their blues rock band Derek and the Dominos, as the thirteenth track from their album Layla and Other Assorted Love Songs( November 1970).',
#  'It first aired on May 1, 2011.',
#  'It is the lead- off single to his 2005 album Modern Day Drifter.',
#  "It served the first single from Minaj's debut album, Pink Friday, with Billboard later claiming it was dropped from Pink Friday.",
#  'It was released in November 1970 on his triple album All Things Must Pass.',
#  'The song reached number 4 on the U.S. Billboard Hot Country Songs chart.',
#  "He also correctly theorized the structure of penicillin Shortly after the team published its first results in 1940, Fleming telephoned Howard Florey, Chain's head of department, to say that he would be visiting within the next few days.",
#  'It was released as a single in 1972 reaching number 8 in the UK Singles Chart, and appeared on their album, Piledriver.',
#  'It was the fifth and final single released from the multiplatinum The Bodyguard soundtrack album.',
#  'It is the second track and third single from their fifth studio album, White Noise.',
#  'It was released featured on the 1995 album Fingers.',
#  'It was the tenth single released to country radio in January 2000 from her album Come on Over.',
#  'It was released on August 5, 2003 as the lead single from their 2003 album The Long Road.',
#  'It features the piano playing and vocals of American artist Wrabel, with Ten Feet Tall becoming the first charting international hit of Wrabel.',
#  'The song was a Top 10 Country hit in 2006.',
#  'These lyrics are considered by Plant himself to be his best overall vocal performance.',
#  " Why did n't she leave?",
#  "The Rächer Basel did n't persist for a long time.",
#  'It then sucks blood into its digestive tract.',
#  "The song was first recorded by The Temptations as a track on their 1966 album Gettin' Ready.",
#  'It was first broadcast on November 5, 2003.',
#  'The presidet would later quote Leonids in various speaches.',
#  'It can not be as late as 1993 is a controversial essay by Richard Dawkins using memetics, epidemiology, and an analogy with biological and computer viruses to analyse the propagation of religious beliefs.',
#  'Lyrics are written by Morsy Jamil Aziz and music is by Baligh Hamdi.',
#  'It was the third track on their 2008 album Rise and Fall, Rage and Grace.',
#  "The track charted in Ireland following the album's release.",
#  'According to Nielsen Media Research, the episode was viewed by by 3.071 million viewers and became the cable lead in the 18- 49 Wednesday night.',
#  'Usually is played by three or more men( women is seldom to play it).',
#  'He was was arrested and booked on charges of first- degree murder and first- degree robbery.',
#  'Between 10,000 and 25,000 Sudanese are thought to be living in London, whilst a fairly vague estimate of 3,000 to 18,000 has been placed in Brighton.',
#  'By issuing a below average number of bases on balls he exhibits good control of his pitches.',
#  'It is used to cool some particular application to cryogenic temperatures.',
#  'Nissa uses the raw energy of her own plane to defend herseelf and her kin from an ancient alien menace.',
#  'The duo album featured two original compositions by pianist/ co-producer Matt Treder.',
#  'It is owned and operated by sushi master Jiro Ono.',
#  "While his short stories have been published in a number of anthologies and magazines, including The Year's Best Fantasy and Horror.",
#  'They are usually used in the JEE context to provide services.',
#  'Many other aircraft that passed near Mount Fuji that day also reported moderate to severe turbulence.',
#  'Allowing the companies to better measure future cash flows.',
#  'The chalice may contain wine, whiskey, water, or other liquids.',
#  'They were fast, yachlike vessels, with three masts and a square rig.',
#  'Short persistence is nothing but noise, though no mathematical justification is made.',
#  'The work done with the co operation of 25 scholars from the academic world of the country is a globally accepted work.',
#  'This production was broadcast the next year Recording of a concert performance in the Golders Green Hippodrome on 2 August 1975 and it was broadcast on 1 January 1976 and issued on CD.',
#  'The adjective crooked can refer to such persons or actions.',
#  'Interested in sports and athletics.',
#  'It is a structure in which a dog is kept or can run into for shelter from the elements.',
#  'The interest will revert to the grantor or the heirs of the grantor.',
#  "By the time Womer was about a year old his parents decided to send him to Sunbury, Pennsylvania to live with his aunt Dolsie( Roxie's sister).",
#  'After being fired from the Our Gang series in 1932, Harry Lucenay retired Pete to Atlantic City, where he was photographed with children at the famed Steel Pier.',
#  'He supported himself by working a variety of odd jobs before finding fulltime employment as a printer with The Ardmore Weekly Courier.',
#  'Fupa digit, an organ of and found in the hands of humans and other primates.',
#  'Taken as a single geographical whole, Kotelny/ Bunge/ Faddeyevsky is one of the 50 largest islands in the world.',
#  'She lives in Chicago with her husband, the writer Martin Seay.',
#  'It is not always possible to properly show this when the strata are extremely fractured, mixed, in some discontinuities, or where they are otherwise disturbed.',
#  'It is towed into the air and then glides back to the ground.',
#  "After poring over several old documents, he comes to acknowledge Thomasina's genius.",
#  'In turn, Yanomami warriors killed at least two garimpeiros and wounded two more.',
#  "They do n't realise at first that they have summonned a djinn which can only be free once the people who summoned him are dead.",
#  'Open air or covered location for gymnastics, athletics, and gymnastic services.',
#  'It focuses on the planning, execution, and aftermath of a theft.',
#  'If more than two persons are involved, this is referred to as a group hug.',
#  'Then, with the help of the warrior, killed several others before they fled.',
#  "She can rightly be called Australia's most popular children's writer.",
#  'Only two of the 11 stories of the second tower remained.',
#  'Over 30 Elands were captured during the failed offensive and some were destroyed.',
#  'He also succeeded to the title of Duke of Ostuni( in the Two Sicilies).',
#  "She is killed by Yoshizumi's assistant just as Shito tells her he will take care of her.",
#  'This album featured Daryl Braithwaite, Simon Hussey, Jeff Scott and James Reyne and was released in 1992 on Columbia Records.',
#  'As a judge, he issued controversial rulings during the Iran- Contra Affair and the Monica Lewinsky scandal.',
#  'It features Grande in an oversized down jacket dancing and singing in front of a row of spotlights.',
#  'The mayor was titled the Sovereign of Naas and carried a ceremonial mace until the post was abolished in 1840.',
#  'While examining the ship, they uncover mysterious symbols carved onto the inside of the stark white interior.',
#  'Since by then, unable to withstand pressure from Atlantic Records she had jettisoned the entire band with the exception of Steve Caton.',
#  'Since by then, unable to withstand pressure from Atlantic Records she had jettisoned the entire band with the exception of Steve Caton.',
#  'He was ordained a priest on December 7, 1947, the first priest from the old Calabar province.',
#  'He is an ardent supporter of legalization and regulation of the industry.',
#  'I included in his output are a number of aphorisms and a book of memoirs, published in 1980.',
#  "This exhibit uses photos, objects, stories, and multimedia to trace the journeys of Iowa's African Americans.",
#  'Though some of these forts are today in ruins, a number of them have been preserved as national monuments.',
#  "They featured in the car chase with James Bond's Aston Martin DBS V12 around Lake Garda, Italy.",
#  'Members claim that they may be pressured into wearing veils, leaving school, and marrying early.',
#  'A poor young man named Zasa once lived in this village.',
#  'They were also where postriders could be hired to take travellers Collins English Dictionary 12th Edition 2014, HarperCollins Publisher by carriage or coach.',
#  'A bus was set alight in the same area and a car was hijacked in north Belfast.',
#  'Laws issued by Cosimo I, Ferdinando I and Ferdinando II obliged those who intended to obtain a degree to attend the Studium of Pisa.',
#  'These QTLs are often found on different chromosomes.',
#  'Later filmed in 1947 as Adventure Island produced by William H. Pine.',
#  'The Musical, based on the film by Baz Luhrmann, prior to a possible Broadway run.',
#  'The play opened officially on April 1, 2012, Haun, Harry.',
#  'Diverging winds aloft ahead of these troughs cause atmospheric lift within the troposphere below, which lowers surface pressures as upward motion partially counteracts the force of gravity.',
#  'Meanwhile on 2 April Stanley returned to Lake Albert, this time with the Advance.',
#  'These range from the popular public domains.',
#  "The latter was included in the Moody Blues' box set Time Traveller.",
#  'The N.C.O.R. was the longest small gauge of the century.',
#  'Therefore, this list does not include notable songs that merely mention Portland in passing.',
#  'It is time for her to stop fleeing and fight back.',
#  "She made her first film,', starring Omotola Jalade- Ekeinde and Genevieve Nnaji in 2010.",
#  'A FunTrivia player that has paid to become a Gold Member has access to more activities than a free member.',
#  "Police have said others were involved in what they consider a murder for hire motivated by Markel's bitter divorce from Wendi Adelson, a clinical law professor at Florida State University.",
#  "At the Arts Theatre in London, she played Sybil Merton in the play Lord Arthur Saville's Crime.",
#  'Shonan Tanteidan are Yoshinori Satoh( lead vocals, guitar), Konosuke Osaka( keyboard, chorus vocals), and Kazuki Aida( drums, chorus vocals).',
#  'They ranged in weight from 4 to 57 pounds.',
#  'Taking the opportunity to take his examination for Lieutenant.',
#  'When the troll threatened him, the boy pulled out some cheese, claiming it was a stone, and squeezed it until whey came out.',
#  'From 2004 to 2007, Sons of Alpha Centauri sporadically performed around Kent with Kent- based artists such as Los Salvadores and Bossk.',
#  "It's also used in parades at Disneyland Paris Resort and Hong Kong Disneyland during the Halloween season.",
#  'He represented Colombia at all youth levels.',
#  'The music video was made available on the Oppenheimer MySpace page.',
#  'For example, sending the output of a satellite TV decoder located in the lounge, to a television in the bedroom.',
#  'A number of its members were influenced by political or cultural nationalism, and some took an interest in the literature of the Irish language.',
#  'Most are from angiosperms, but a few come from gymnosperms.',
#  'At this point, the disease is typically fatal.',
#  'She reported hearing a car outside her window with a loud backfiring muffler.',
#  'This monster causes an earthquake, separating Cecil and Kain.',
#  'A new set dubbed as the WAR( Wireless Audience Response) room was specifically designed for the said election coverage.',
#  'United States Department of Agriculture, the World Bank, United Nations Development Programme, the European Bank for Reconstruction and Development, the Asian Development Bank, and other development funders.',
#  'In the U.S. particularlyInfectious Disease professional organizations like the IDSA, the PIDS and theCDC and globally the WHO.',
#  'But it is now becoming a spare bus of the depot and used occasionally.',
#  'But he wants to go to another island where there are lots of ants.',
#  "The team main event- ed in the third episode of WSX, in a Tables, Ladders and Cervasa's match ending their feud with Luke Hawx and Alkatrazz.",
#  'He currently is the offensive line coach for the Buffalo Bills of the National Football League( NFL).',
#  'Aasim first began rapping at the age of 12, and signed a record deal with Schott Free of Loud Records at 17.',
#  'The club was founded in 1953 and is almost exclusively concerned with the game of hurling.',
#  "Abercrombie's first notable recordings were two albums with the jazz- rock band Dreams in 1970.",
#  'From there, CFC launched Ablaze Communications, a subsidiary of the organization involved in production of audio- visual presentations and merchandizing of products that serves as a tool for a pastoral growth.',
#  'It can also be caused by any developmental abnormality that impairs the ability of the fetus to swallow( because the fetus normally swallows amniotic fluid and absorbs it through its intestinal villi).',
#  'A further residential unit of single cell accommodation which is used as an Induction Unit for newly arrived prisoners.',
#  'And there is a Minish- sized chamber inside them where they can be turned on or off.',
#  'Before Corll vacated the address on June 26, Henley assisted Corll and Brooks in the abduction and murder of a further two youths named Billy Baulch and Johnny Delone.',
#  'Sherwin reasoned that insects had preferences, habits, and memories, and could experience negative mental states.',
#  'And according to Aeschrion of Samos, Glaucus was the lover of the semi-historical Hydne.',
#  'Oswald replied by insisting that he wanted to live in the Soviet Union as a Soviet national.',
#  'By the next morning only a few areas remained under rebel control.',
#  'From its earliest years of Makiguchi it challenged the imperial system along with established institutions such as public education, the military, and clerical authority.',
#  'These held a meeting in Bonao, a small town in the Dominican Republic in June 1976.',
#  'Other sources state the air battle over Belgrade lasted just two days owing to poor flying weather on 8 April.',
#  'Thus, HIPAA privacy laws do not apply to it.',
#  'They placed him in a cauldron suspended from two of the stones on account of him being a particularly oppressive and cruel landlord.',
#  'After their detonation, they opened fire on worshipers at al- Rawadah mosque in Bir al- Abed.',
#  'The information obtained from the SIM of Iftikhar Hussain has brought previously unknown facts and connections into the limelight.',
#  'However, many compilers will not let you assign thsi return value to a local variable, as the constructor for typeinfo is private.',
#  'Besides, it ranked 7 th in reputation, 7 th in papers published on SCI journals and 4 th in outbound exchange students ratio( 5.1%).',
#  'He wrote that they could study, earn ijazahs( academic degrees), and qualify as scholars( ulema) and teachers.',
#  'The county is located some sixty miles north of the geographic center of Texas.',
#  'However, by 2012, growth slowed down dramatically as reforms have come along at a slower pace.',
#  'The President serves a term of five years.',
#  'With the addition of extra dates, the new Australian leg grossing stands at just over$ 70 million.',
#  'The Summer Show reverted to Holland House.',
#  "Acharavi belongs to the former community of Agios Panteleimonas( pronounounced:' Agios Padel'eimonas, greek: Άγιος Παντελέημονας).",
#  "This forms a single' actin filament'( previously referred to as' microfilament').",
#  "However, Palpatine accuses Windu of treason before mercilessly killing Windu's companions and fighting the Jedi Master.",
#  'It can be used to present 3D images on CRT, plasma, LCD and other types of video displays.',
#  "At one point he calls Jill and tells her he's a god.",
#  "This was Decatur's first soccer state championship.",
#  'It was the first time since 7 March 2011 that they both held the top- 2 spots in the ATP rankings.',
#  'This shows that Greeks distinguish doulos from slave.',
#  'There is no public parking and is only accessible through public access paths.',
#  'This process is repeated until the board is satisfactorily flat.',
#  'All the municipalities are in the canton of Bern.',
#  'The destroyers in the Hornet and Enterprise screens were commended for a stellar effort.',
#  'Kiefer was also an inventor and innovator of new products related to aquatics competition.',
#  'He wrote a book about the Wiriyamu massacre during the Mozambican War of Independence.',
#  'Forest clearance may lead to local habitat loss, but this is a common species with no major conservation concerns over most of its range.',
#  'Afia appeared in five episodes between 29 December 2009 and 5 January 2010, and returned on 18 November 2010.',
#  'The famous duo act now consists of original member: lead vocalist Elyse( aka Linda Meek) and newcomer: rapper/ singer Elijah MC.',
#  'Knowing it is too dangerous to leave in the hands of mortals or angels, he takes the Black Soulstone back to Sanctuary and attempts to seal it away where it can never be found.',
#  'Stacy joined their alliance and suggested targeting Edgardo, resulting in the systematic eliminations of the three loyal Horsemen.',
#  'Consequently, he becomes famous and makes celebrity appearances on The Tonight Show with Jay Leno and the MTV Movie Awards.',
#  'There were an additional four rescue squadrons not assigned to the wings.',
#  'The R8 terminates further north at, so that the R2 only shares tracks with the R11 and freight services from this point on.',
#  'There, the children inevitably drink cursed water which turns them into donkeys.',
#  "His house is in St John's Wood and was visited by John Betjeman in his film Metro- land.",
#  'The band experimented with altered states of consiousness and frequently rehearsed through the night jamming over the same riff for extended periods of time.',
#  'On 9 July 1958 Cherkassy Regional Trial rehabilitated him.',
#  'Following the decision taken at the Teheran Conference of 1943 at the insistence of the Soviet Union.',
#  'Persons convicted and sentenced to non-custodial sentences often are not termed convicts.',
#  'When Arnav decides to go on a trip overseas, he manages to get kidnapped.',
#  'On 5 June 2017, Musolli received a call- up from Kosovo for the 2018 FIFA World Cup qualification match against Turkey.',
#  'He was masquerading as a Hauptmann( Captain) Schämmel.',
#  'She would move on to a Blues- blues sound with True Love in 1991.',
#  'The mixed response to her films and performances at this time generally led critics to believe that the end of her career was imminent.',
#  'In addition, they have been hit hard by the drop in commodity prices and a collapse in foreign direct investment.',
#  'Hahn settled Scotland, where he and founded Gordonstoun on similar principles to the school in Salem.',
#  'It was officially renamed to its present name on April 6, 2005.',
#  'Shortly afterwards, Rev. Wilhelm Poland arrived in 1889.',
#  'He then spent the next 60 years roaming the Pacific, seeking out Polynesian settlement sites, excavating relics, and photographing petroglyphs.',
#  'After studying theology in the Jansenist schools for some years, his interests seem to have turned away from the Church.',
#  'He played 13 games for the Bills at linebacker that season, starting two games.',
#  'The family first stayed with Karin Michaëlis at her house on the small island of Thurø close to the island of Funen.',
#  'Patrick St. and build a new feed mill and office block in the Belfast Harbour Estate.',
#  'After purchasing the air rights in 1961 Marvin Kratter bult four high- rise apartment buildings over the expressway.',
#  'Berg first turned to Emmett/ Furla Films, who co-financed the film with film financiers Herrick Entertainment and Envision Entertainment.',
#  'It drains into the Balsas River which, in turn, empties into the Pacific Ocean.',
#  "After eliminating teams like Anderlecht and Steaua Bucureşti, they reached their sixth final in the competition, where they met PSV Eindhoven in a match played at Stuttgart's Neckarstadion, on 25 May 1988.",
#  'His project covered people, having a sum assured of Rs. 50,000/- per family, through Oriental Insurance Company.',
#  'He worked with many of the artists of the YBA movement including Tracey Emin, Sarah Lucas and Gavin Turk.',
#  "While playing for the school's football team, the Rams, Fanucchi was sought by several high- profile collegiate football programs, including the University of Southern California.",
#  'She works with Fortune 500 companies nationwide, staffing their tech departments.',
#  'By the year of 2001 she returned to Israel.',
#  'He then translated the entire work from traditional Chinese to English.',
#  'He and his fellow Muladis were killed at Córdoba when the Berbers took the city.',
#  'He played 8 games in 1984 and 1985, before a knee injury ended his football career.',
#  'However due to homesickness, McStay ended his contract with the Belgian club at the end of January 2008 and went in search of a new start in Britain.',
#  'They took their first lead breaking a 20-- 20 tie on route to a 30-- 27 win.',
#  'She successfully negotiated for survivors to be given access to ground zero, which they previously did not have.',
#  'An auxiliary lane is added between St. George Boulevard and Green Springs Road with additional interchanges at Washington Parkway and State Street( SR- 9).',
#  'Brown eventually returned to the struggle for black liberation, especially espousing the need for radical prison reform.',
#  'Using both small arms and time- fused artillery shells, the Spanish long- range fire caused several casualties.',
#  "Playing Stavinsky's Firebird Suite, the corps finished in fifth place in Kansas City.",
#  'The Cavaliers got off to a strong start winning their first four games on their way to a solid 15-- 7 start.',
#  'According to The Sydney Morning Herald, his studio attracts hundreds of new students each year.',
#  'The album Rise of the Great Machine was released in 2000 through the Undecided label.',
#  'Using their instruments, he learned music by experience and after a while he became the guitar player in the band.',
#  'In 1858 he was an assistant at the department for the mentally ill under Wilhelm Griesinger( 1817- 1868) and Karl Wilhelm Ideler( 1795- 1860).',
#  'Saint piece together parts of puzzle and realize that Gabriel must be taking Shandala to BIOCOM building.',
#  'The old location was kept on as an archive.',
#  'Holland began his coaching career as a defensive quality control coach for the Green Bay Packers from 1995- 97.',
#  'However he later returned to Wolves as managing director in 1994, a post he held until 2000.',
#  'His coaching career as a youth and reserve team coach at Oxford United, where Denis Smith was manager.',
#  'At first he became afraid of it but in time it made him gain a new attitude in life, even rude at some times.',
#  "Encouraged by his clients, he started writing, first for Women's Wear Daily and then for the Chicago Tribune.",
#  'He worked in a Roman milieu where late- Rococo of Pompeo Batoni and the incipient Neoclassicism of Anton Raphael Mengs coexisted, and fashioned a style in between.',
#  'At that time, the Black Hawk War was beginning in the West.',
#  'He overpowers the guards and escapes, disguised in one of their uniforms.',
#  'This changes the D- loop to a cross-shaped structure known as a Holliday junction.',
#  'He was elected to the New York State Assembly to represent the 16th District in Northwest Nassau County in 1986.',
#  "He was also the team's top goalscorer with 25 goals.",
#  'This was the practice by which employees were forced to accept payment or advances in kind, often becoming effectively enslaved to the company store.',
#  'He helped the national side finish runner- up in the tournament, to hosts Holland.',
#  'A large number of other ships were eventually recovered from a POW camp in the second season.',
#  'He completed his Matriculation and joined the Post and Telegraph Department.',
#  'Bratislava Regio was abolished in 1928 and replaced by a new territorial unit called the Slovak Land.',
#  'Residents of Chinatown waited about thirty years for a replacement.',
#  'On 30 December 1991, BIOTEC became one of the NSTDA centers, operating outside the normal framework of civil service and state enterprises.',
#  'Sonniel is king and reigns supreme.',
#  "As one of them attempts to unlock the door with his key, they hear a strange noise, which is actually a cartoon tiger on the car's bumper sticker roaring.",
#  'The pair were escorted from the stage separately by security staff.',
#  'If the guest had received an empty door, a taped response from the second person was aired, in which the person explained why he would not come to the door.',
#  'A third trial to re-determine the amount of damages was set for October 4, 2010.',
#  'The centre of gravity in the empire was fully recognised to have completely shifted to the eastern Mediterranean.',
#  'More than 50,000 displaced people were able to return to their homes.',
#  'However, over 70,000 Loyalists sought refuge elsewhere in the British Empire, often with financial help from the Crown.',
#  'They were scrapped in 1933 under the London Naval Treaty limiting naval armament.',
#  "He became a King's Counsel( Queen's Counsel from 1952) in South Africa, in 1910.",
#  'He held this post until 1930, serving several successive Chancellors including Winston Churchill.',
#  'Firstly, as part of Rashka and later as part of Serbian Empire.',
#  'Williams pursued other projects before committing suicide on April 1, 1998.',
#  'His success was based largely on having picked up the slider from Rusty Staub.',
#  'However, when she realizes that she is pregnant, she is forced to resign from that position and give it to Mirai.',
#  'This time by Great Wall Marathon first- timer Romualdo Sanchez Garita from Mexico.',
#  "The station is served by Via Rail's The Canadian three times per week as a flag stop( 48 hours advance notice required).",
#  'AgilOne sells customer data platform software to enterprise B2C brands.',
#  'The series was won by Ukrainian sand artist Tetiana Galitsyna, who received PLN 300,000.',
#  'People depend mostly on ground water.',
#  'However, as Wild Child was preparing to finish the job, Omega Red interrupted him.',
#  'This movement produces displacement antinodes in the standing wave.',
#  'And receiver/ return Leon Bright captured the Schenley Rookie award.',
#  'He also acts as a top adviser to Sheikh Mohammed bin Rashid Al Maktoum, the leader of Dubai.',
#  "He was commissioned in the Pakistan Army's famed Frontier Force Regiment in April 1975 in the 51st PMA Long Course.",
#  'Ketcham was a student of Edward Angle at his Angle School of Orthodontia.',
#  'Nevertheless Albert had in fact worked up a ruse- to the Dutch eyes there was confusion about where he would strike.',
#  'He was the eldest child of Dr William Haliday( 1763- 1836) and Marion Webster.',
#  'Hons in Biology and Columbia Universitypursuing a M.Sc in Biology and graduating with a doctorate in zoology in 1921.',
#  'She was a Republican State Representative from District 35 in Pennington County, South Dakota from 1999 to 2006.',
#  'She is also a Marvel Comics character.',
#  "Although fairly affluent for most of his career, he fell on hard times towards the end of his life and was buried at his daughter's expense.",
#  'In most states, the law states that the ammunition( and bolt if readily removed), must be stored either in a separate safe or in a separate locked section of the safe.',
#  'The prisoners were taken to Culiacan prison.',
#  'The constant thoughts about the limerent object define all other experiences.',
#  'In the English context, it came to refer to inhabitants of British North America, and then the United States.',
#  'They are down filled with Ukrainian grey duck and with 320 more feathers is both the parkas and the bombers.',
#  'However unofficial perforations were produced locally.',
#  "Whereas female competitors attempt to become Jan's sister who is described as both lethal and delicious.",
#  'For example the Disney Studio artists, who made comics directly for the European market.',
#  "In spring 2012 the group released their debut album,' Genius by the Mile' and is currently playing live shows.",
#  'River at the foot of the falls.',
#  'His mother died when he was two, and he was raised by his grandmother.',
#  'She was born on October 22nd, 2013.',
#  'He attended Eisenhower Senior High School, where he was heavily involved with Speech and Drama and directed the senior play as a sophomore.',
#  'This register allocation is either performed by a compiler, in the code generation phase, or manually, by an assembly language programmer.',
#  'He became the youngest Mayor in the country in 1985 at the age of 26 when he was elected as Mayor of Knaresborough.',
#  'She is also a 24 hour personal- companion to whatever Johan demands her to do, be or perform at any particular moment.',
#  'They also called the US government to stop supporting the state of Israel.',
#  'Changes to the Lisp code do not require the editor to be restarted or recompiled.',
#  'There are no convenient, constant current sources in nature( excepting inductors, Van der Graaf generators and photodiodes).',
#  "He has worked on projects with such producers as Brendan O'Brien, Owen Morris, Brad Wood, Thom Panunzio, Jimmy Jam and Terry Lewis.",
#  'It belongs to the class of rapidly oscillating Ap stars.',
#  'It consists of the Tony Balthasar Lodge and the Kanangra& Bluegum cottages.',
#  'A hyperactive fetus should be evaluated with ultrasound to rule out cord entanglement.',
#  'It was the notorious pirate whaling vessel Sierra.',
#  'Including the scarred state football trophy that they won by default.',
#  'Agular arrives in Mexico in 1945 by the hand of the Cuban dancer Julio Richard.',
#  "In return for his silence, Dan Dority does not make known to Swearengen of Ellsworth's status as a witness.",
#  'Matrilineal Maya societies include Toniná, a city which became matrilineal after the death of the powerful leader, Lady K’awil.',
#  "Many of Angelou's readers identify her as a poet first and an autobiographer second, but like Lynn Z. Bloom, many critics consider her autobiographies more important than her poetry.",
#  'The Conservative party also refused to run a candidate in Fermanagh South Tyrone despite running in 16 out of 18 constituencies.',
#  'However, Kabalian is not mutually intelligible with either Waray- Waray, Cebuano, or Surigaonon.',
#  'The remainder of the territory was designated Washington County( on the Maryland side of the Potomac) and Alexandria County( on the Virginia side).',
#  "In a Christmas special Pinky even wrote to Santa that Brain had the world's best interests at heart.",
#  ' sumbal the prevalent view today is that Old English symbel, Old Saxon symbal, sumbal Heliand, line 3340: sittan at sumble.',
#  'And a few years later in 1779 the village was officially founded.',
#  'Island Press, camping, and hanging up plants in our homes provide support for this theory.',
#  'However, as the prosecution has powers to appeal the resulting acquittal, it lacks the finality found in the United States.',
#  'Thereafter, he devoted his creative energies to teaching, and held several academic positions.',
#  'He appeared publicly for the last time at the funeral of Richard Nixon.',
#  'His most famous play is Yellow Sands.',
#  'Its residents and as well as those from other villages fled to the city of Samsun for refuge.',
#  'Each incoming stimulus calls upon the same directed attention mechanism.',
#  'They re-married in a simple civil ceremony in San Francisco on December 8, 1940.',
#  'The family included John Poynder Dickson, 1st Baron Islington.',
#  'It is estimated that there was enough kid power that one could gain kid power by just being in the vicinity of the crusade.',
#  "Overall, though it appears she undertook very few duties during Richard's short nine- month reign.",
#  'Farms and ranches speckled its canyons reinforcing the need for its very own post office.',
#  'It is often found on the walls of mines and quarries as a secondary mineral.',
#  'Currently, he is in the 2014 Broadway revival of On The Town.',
#  'Today, it is the leader in terms of number of bookings worldwide.',
#  "O'Leary is currently the head coach of the Florida Gators women's lacrosse team that represents the University of Florida located in Gainesville, Florida.",
#  'She is credited with coining the speech recognition phrase O.K., Glass.',
#  'In October 1952, Britain became the third country to test an independently developed nuclear weapon.',
#  'Also, Professor John R. May concluded that Madonna is a contemporary gesamtkunstwerk.',
#  'So please mind your language when talking to him.',
#  'It is a hill on the East- West road in Eriador, about midway between the Shire and Rivendell.',
#  "Johnson finished just behind Clyde C. Holloway, the fourth- place candidate and a Republican member of the Louisiana Public Service Commission from Johnson's neighboring Rapides Parish.",
#  "A future Eclipse Award winner, Bertrando came into the Breeders' Cup having won the Grade I Norfolk Stakes and the Del Mar Futurity.",
#  'Her performance was digitally added to scenes in the Jedi Temple and during the climactic battle on Geonosis.',
#  'The principal is the person the agent is employed by or acting for.',
#  'The video also portrays Ciara dancing on a roof top.',
#  'The album was certified gold by the RIAA in early 1973 for selling over 500,000 copies.',
#  'It is the combination of two contradictory terms: ursuz( surly) and amuz( I amuse).',
#  'The family was first recognized by the crown during the reign of Henry VII after Thomas Salusbury put down a rebellion in Cornwall.',
#  'It had a tailskid undercarriage, with pairs of mainwheels on axles attached to longitudinal bars fixed under the engines on N- form struts.',
#  'There are significant differences between the actions, powers, obligations and liabilities of brokers and estate agents in each country.',
#  'This can, but does not have to, include a heritage, a common culture, a shared language or dialect.',
#  'Jacobs actually won by disqualification when Guerrero beat him with a chair.',
#  'The Flounder reminding the Tuvaluans of the flat atolls.',
#  "The town's population grew to over 4,000 circa 1881.",
#  'Limited structural complexity and limited longevity are essential for the survival of a species.',
#  'The update outlined many new developments including the impact of the 2009 post-election violence and persistent tensions surrounding the Iranian nuclear program.',
#  "Sara's mom was selling vegetables at the market for a living.",
#  "It is situated adjacent to the Northern Quarter and the northern part of Manchester's commercial centre.",
#  'Lead editor Naomi Zeichner went on to compare the album to the work of Interpol and the retro biker bar rock that soundtracks Sons of Anarchy.',
#  'He stands accused of being a member of the Gülen movement, which the Turkish government considers to be a terrorist organization.',
#  'Born and raised in Alexandria, Egypt, he is currently distinguished professor at the Graduate Center of City University of New York, where he teaches the history of literary theory and the works of Marcel Proust.',
#  'Neher was born in 12, rue du Marché, Obernai, Bas- Rhin.',
#  'This reduction in Ang II levels suppress the feedback loop.',
#  'He was enslaved and was the first valet and royal tutor of Aloys I, Prince of Liechtenstein.',
#  'Those whose sum is a straight angle are supplementary.',
#  'Consisting of Victor Cobos and Carlos Piris, Kike Planelles Manuela Soriano.',
#  'Staff had to prevent walruses from bathing in their pool because the water was too warm for them.',
#  'She studied computer science at Universität Paderborn and received her Diplom in 1990.',
#  "Born in 1920 she was brought up in the King's Mill House in the village of Great Shelford, Cambridgeshire.",
#  'When done in dry weather, shaking may remove pollen or dirt from feathers.',
#  'The first one also claims that Maxwell was a lesbian who tried to seduce Callas herself.',
#  'She is best known for her work as an abstract expressionist, a colourist and, after 1995, as an icon painter.',
#  'She was Duchess of Rohan- Rohan and Princess of Soubise by marriage.',
#  'She was the sister of an official of Trondheim, Sören Pedersson.',
#  'In his book a poem is provided to solve a simple remainder problem.',
#  'According to his account, there were Arbanasi merchants trading in Italy, Hungary, Poland and particularly in Muscovy.',
#  'During that era the magazine enumerated the love affairs of Brigitte Bardot, all the while keeping moralising criticism of the star to a minimum.',
#  'Factors such as soil structure or biological activity affect the rate at which nutrients leave the soil.',
#  "The title of king of Cobo makes it's first appearance in the Annals of Tigernach under the year 685AD, and in the Annals of Ulster under 735AD.",
#  'He said he had sold Simpson a 15- inch( 380 mm) German- made knife, similar to the murder weapon, three weeks before the killings.',
#  'Such persons can make a case even if they do not fall into one of the nine specific groups which are covered under the legislation.',
#  'The same arrangement appears in More Friends music from FINAL FANTASY~ Final Fantasy Orchestra Concert in Los Angeles 2005~, performed in English.',
#  'This was demolished in 1989 and the exact location it stood is unknown but was in the parameters of Brockdorff Street.',
#  'There he became a judge and subsequently Adjutant General of the United States Army under General William Henry Harrison in the War of 1812.',
#  'It has traces of western sound found in genres like Rock, Jazz, Blues as well as Indian sound ranging from Sargam, Alaap and Dhrupad based Tarana.',
#  "During the 1980s he worked for Alligata, Gremlin Graphics and later Crowther's own company, Wizard Development.",
#  'He was a Fellow of the Royal Photographic Society.',
#  'He moved to Danbury, Connecticut, in 1887 and was employed as a journeyman hatter.',
#  'He is a popular guest star at Western film festivals and the like.',
#  "All newly credentialed and future anesthesiologist assistants must complete an accredited Master's program for anesthesiologist assistants.",
#  'It grew, on average, 13 percent per year between 1985 and 2005.',
#  'It is located in the northeastern part of the country, about 350 km( 217 mi) north of Salvador.',
#  'Where Simulation racing games might include Tire wear or fuel gauges that require you to quickly react to pit stops.',
#  'As of 2016 it has 4796 cultural centers and a million members in all Italian Regions.',
#  'Argentina lost in the final to Brazil.',
#  'It is managed by the Wildlife Trust for Bedfordshire, Cambridgeshire and Northamptonshire.',
#  'He used her as a messenger; asking her to make contact with his followers, the young King and the Russian embassy.',
#  'There is no evidence that such a game has ever existed.',
#  'It was not be published during the First or the Second World War.',
#  'The company has also gained the contract for route 230 from 22 June 2013.',
#  'He leaves his son to keep watch, but the boy falls asleep and they are robbed of everything.',
#  'SS men stormed the hotel and Hitler personally placed Röhm and other high- ranking SA leaders under arrest.',
#  'In this work, the authors gave the first English language account of Japanese film.',
#  'Him and his mother were abandoned by his father.',
#  'He later became a member of CIBJO, the World Jewellery Confederation, representing the United Kingdom.',
#  "Later, Julius Penrose( Arthur's other partner) has been aware of the embezzlement for some time.",
#  'The surrounding area became the center of the popular Cornish Art Colony.',
#  'It is the second- busiest airport in Uganda, behind Entebbe International Airport.',
#  'APP represents the merger of two previously separate institutions for men and women, and serves students in and around Palani as well as from the Dindigul, Theni, Madurai, and Coimbatore districts.',
#  'Felicity is locked in a chamber with poison gas.',
#  'Simultaneously, units of the Royal Canadian Dragoons were forced to wheel into the woods at the north due to German attack.',
#  'These students expect that a degree from a prestigious college in the United States will give them an edge over others in searching for a job.',
#  'He starts dating Jeannine( Elizabeth McGovern), a beautiful, kind and nonjudgmental girl from his school choir.',
#  'He died on 7 January 1971, at 5.50 p.m. of heart disease.',
#  'Currently many countries, including the United States, do not permit the manufacture of generic biologics.',
#  'To avoid that stereotype, he taught himself to imitate the speech of American news anchors.',
#  'She settled in Germany for her university studies at the University of Berlin.',
#  'Músquiz then forwarded it to the Mexican Congress in early 1833.',
#  'He helped lead the team to a 4-- 5 record.',
#  'He was a versatile player, playing different positions along the defensive line during his career.',
#  'He sent her in 1806 to Grand Turk, which Bermudians had used seasonally for a century for the extraction of salt from the ocean.',
#  'He took part in the Battle of Länkipohja and Battle of Tampere and received the rank of Lieutenant- Colonel.',
#  'Additionally, Soap is indefinitely banned from the English Wikipedia.',
#  'These predatory snails continue to represent a threat to the local snail fauna.',
#  'This phenomenon is often referred to in economics literature as Dutch disease.',
#  'A phenomenon that is often referred to in economics literature as Dutch disease.',
#  'He continued his effort in the Senate Judiciary Committee, where he also met opposition.',
#  'Their immediate area of influence was about and their weapons had a short range even early in the age of artillery.',
#  'However, Army officials did not understand how often they needed to do so.',
#  "Surrounded by the rich history and colourful names of his new surroundings, Fidler developed an appreciation for Newfoundland's music and culture.",
#  'He subsequently played eight times for England.',
#  'The storyline also changed; originally, the spider sequences were to be present near the end of the game, but were later moved to the first part.',
#  'Four years later, Britain and France were indeed on the verge of war during the Fashoda Incident.',
#  'If one finds Vega, Eltanin is the red star just north- northwest of it.',
#  'The Frenchmen then launch the rabbit out of the castle by means of a catapult.',
#  'So he allowed them to be oppressed by the neighboring Midianites and Amalekites.',
#  'Due to ideological differences, al- Nusra has run afoul with ISIL and become one of many other regional adversaries for the group.',
#  'However it includes versions of articles that have been previously deleted.',
#  'The villa was named after an elm tree planted in the middle of the ornate gardens, which is no longer alive today.',
#  'Then Anas Bin Harun, Ishfaqur Rahman along with other students made an effort to unite all the students and opened a confederation named RBM Student Confederation.',
#  'By that time they were quite elderly and numbered fewer than ten.',
#  'He claims that Amnesty International USA acted in ways closely related to United States and United Kingdom foreign policy interests.',
#  'However, the film failed to revive his career, and he died three years later.',
#  'Use of this term has been criticized for delegitimizing gender- variant people with different experiences.',
#  'The greater number of men is possibly due to the significant gender imbalances evident in the Indian and Chinese populations.',
#  "GIP's investments are largely concentrated in OECD countries.",
#  'The park does not charge an admission fee.',
#  'They kidnap him while Billy is flirting with his crush in the park.',
#  "Berating her for giving up, he tells her to use the Soyuz's landing rockets to propel the capsule toward Tiangong.",
#  'Bad breath may be the third most common trigger to seek dental care,( after tooth decay and gum disease), showing that patients place great importance on it.',
#  'The 23rd Brigade retreated to avoid being rolled up.',
#  'However, they eventually managed to reach the Russian First Division after 2 consecutive promotions.',
#  'Both hands come across the body, intersecting at the forearms and providing a firm defence.',
#  'He is also interested in economic, cultural and cultural ties between the UK and China.',
#  'For example by way of neighboring socialist countries, using forged documents or hiding in vehicles.',
#  'Equivalent to a Category 1 hurricane, at least in gusts.',
#  'In some cases the gains are said to have been 500%.',
#  "There they are spotted by Jeff's old partner, Fisher.",
#  'The two are from the same suffix branch.',
#  'The demonym is predicated of the prophet to denote that his residence or possibly even birthplace was Tishbe.',
#  'And can be constructed from the same semiconductor materials as the light- confining structures.',
#  'He refused the requests of the Quraish clan to send these refugees back to Arabia.',
#  'He has lived in several countries and has made public appearances around the world to speak about freedom of the press, censorship, and investigative journalism.',
#  'New surveys have shown there are three higher peaks on the border with Albania.',
#  'The crash site was 559 m above sea level, almost 35 km from Zürich/ Kloten Airport.',
#  'Police stated that no other shooters were believed to be involved.',
#  'Before that she worked at the salon of her young auntie.',
#  'Here she made her first real friends and nurtured her love of poetry.',
#  'He was selected for the second consecutive year as an All- Big Ten player.',
#  'Within two hours the mob was moving about the city, sacking shops and breaking into armories and a local gun factory to procure arms.',
#  'On 4 of July, Terminal Tower is lit in red, white and blue.',
#  'There, a series of virtuoso performances helped to keep the club in the Championship, and he also gave many autographs to fans.',
#  'Taken prisoner during the ill- fated attempt to storm the city on January 1, 1776, Henry remained confined for nine months.',
#  'He was brought up by his grandmother, after his parents died of tuberculosis when he was a baby.',
#  'However, he soon realizes that the man is actually the devil.',
# ...
#  'He went on to study anthropology at the University of Iowa on an Army ROTC scholarship, graduating as the Distinguished Military Graduate with a BA in 1992.',
#  "Despite being a sensitive woman, her heroine is beginning to realise that her gender's role may not always be submissive.",
#  'He was an all- conference pick three consecutive years.',
#  'As of 2007 he is yet to catch the eyes of the national selectors, although he has represented the Rest of Pakistan.',
#  'Usually they are sold in small sizes for customers who wish to experiment.',
#  'It was ceded to the UK in 1814.',
#  'A ten- acre Forward Operating Base Border Wolf, a Forward Operating Base supporting Operation Jump Start.',
#  'He is promptly caught by the Queen, but she offers leniency if he has sex with her.',
#  "In the storyline, Aidan began a relationship with Mandy, signifying the start of the character's misfortune and decline.",
#  'He contributed to the formation of the Falange.',
#  'Chichester was the second son of Arthur Chichester, 4th Baron Templemore, whom he succeeded in the Barony.',
#  'It is the final phase of The Mailbox development.',
#  'Although the tower/ observation deck extends above the 28 office floors( claimed to be approximately 44 stories in total).',
#  'The cathedral was built after his death in 1862-- 1868.',
#  'He also paced the squad in games pitched and strikeouts.',
#  'In November 2015, he made his debut for the senior team.',
#  'While cashew nuts( but not cashew fruits) may trigger allergic reactions while rose apple fruit has not been observed to do so.',
#  'Its bizarre imagery and longevity lead to it becoming a minor tourist attraction.',
#  "The King ends up in a cursed life as a ferryman when he grabs the cursed ferryman's oar freeing the previous ferryman.",
#  'On average, Albanians enjoy a great deal of sunshine, second only to Spain in average annual sunny days.',
#  'He was discovered the next morning hiding in a sleeping bag beneath a camouflage tarp in Laurens County, Georgia, by police, and arrested for the murder of Dinkheller.',
#  'The funds simply were not available due to other WWII projects, as well as the belief that the tides of the war were beginning to turn in favour of the Allies using more conventional methods.',
#  "Yet, Buffy and Xander both agree that Jonathan and Andrew do n't deserve to die since they never killed anybody.",
#  "' He published a map of La Rochelle, and was recorded working in Paris between 1556 and 1580.",
#  "When the first production batch rolled out, Jack and Jason's Pancakes& Waffles was officially up and running.",
#  'Considering these functions can lead us to ask new kinds of questions about how development works, as well as how it may function in evolution.',
#  'Eva is voiced by Sarah Lafleur.',
#  'Totem, an idol, was designed to explore the implications of language and artificial intelligence using machine learning technology.',
#  'The specific instant is defined by the administration, at present the moment a person has the ability to perform simple algebraic calculations( around the age of 12).',
#  "She was baptised in 1766 at St. George's Church, Bloomsbury.",
#  'DVI was the first multimedia desktop video standard for IBM- compatible personal computers, developed around 1984 by Section 17 of The David Sarnoff Research Center Labs( DSRC) then a division of RCA.',
#  'It is often confused with the similar technical processes, selective laser sintering( SLS) or selective laser melting( SLM).',
#  'He also smelled of rum, like he had been drinking.',
#  'Also, Trinectes maculatus often has no( rarely one) ray( s) in its pectoral fin.',
#  'The very first volume in the series was released on January 5, 2011.',
#  'In the years 1997- 2002, an estimated 229 km² of evergreen forest was lost through illegal logging(~ 30 km²/ year).',
#  'He now works for Human Rights Watch in New York City, as Advocacy Director of the LGBT rights program.',
#  'Both were armed with semi automatic handguns.',
#  "She breaks everything she touches if she's not careful.",
#  'He is a member, and one of the main vocalists of the South Korean- Chinese boy group EXO.',
#  'It was created and owned by Jimmy Salcedo.',
#  'The informant was immediately released from jail, her sentence commuted to time served.',
#  'Dobbs is caught trying to put it back and Palmer stabs him to death.',
#  'These creators were the surveyors and astronomers of the pre-druidic British Isles.',
#  'Wild and feral dogs can usually get all the nutrients needed from a diet of whole prey and raw meat.',
#  'But perhaps because dolphins stopped showing up in great numbers off Iki.',
#  'He uses his Rhino Blade to enhance the effects of his moves.',
#  'LaCapra received his B.A. from Cornell University and his Ph.D. from Harvard.',
#  'His debut album Rolling Papers was released on August 30, 2010.',
#  'It was located in the province of Ontario.',
#  'Upon his death, he was succeeded by the Prince Arthur, the Duke of Connaught and Strathearn, a previous Governor- General of Canada.',
#  'He and the Black Guelphs returned to Florence with Charles of Valois in November 1301 and took power again, exiling and killing many White Guelphs.',
#  'It was started by Tim Riley, a first- time entrepreneur who had previously worked for Shurgard Storage Centers.',
#  'However, when it was separately established, it came from parts of the neighboring Colleton and Berkeley counties.',
#  'He previously played first- class cricket for the New South Wales Blues and international cricket for Australia.',
#  'He served as Offensive Coordinator for the Tennessee Titans from 2012- 2013 as a part of Mike Munchak coaching staff.',
#  'Civic leaders have expressed hope that the district will emerge as an important arts and entertainment district in the Youngstown- Warren metropolitan area.',
#  'They began to practice in Karachi, which at that time was the capital.',
#  'His clinic was at ACHI QABAR, beside the Boulton Market.',
#  'The Eighth Circuit had ruled that the law would be unconstitutional without a judicial bypass, but that the bypass provision saved it.',
#  'They entered into a rekindled relationship at an undisclosed point midway through the series.',
#  'Among them Dr. William Canfield and Dr. Yuan- Tsong Chen.',
#  'He was born in Kha- ye village in Moulmein( Mawlamyine), Burma, where he was brought up by four spinster aunts.',
#  'Wood also focuses on culture, personal relationships, and feminist theories.',
#  'A specialist in Indian aesthetics and literary theory.',
#  'He explores the way our perceived and conceptual worlds are constructed through language.',
#  "Often held in the week before Spring Break and kept a closely- guarded secret until the dragon's appearance, in recent years Dragon Day has been scheduled for the Thursday before St Patrick's Day.",
#  'The dragons often seem to smile.',
#  'The company was founded to meet market demand by changing the rules of the game for staffing, hardware requirements, and transfer speeds.',
#  'As a legal term, it is used within the United States and the United Kingdom.',
#  "Often Drug courts are the only avenue for entry into treatment in the United States, which does n't have adequate health services.",
#  'He made his debut in Round 1 when the Bombers were comfortably defeated by Port Adelaide Football Club Port Adelaide.',
#  "One of the areas that I'm most knowledgable in assisting is information in this industry as well as most other marine related information.",
#  'The main one is next to the main harbour of Sokodo.',
#  'The named Arlene was re-used for tropical cyclones during the 1967, 1971, 1981, 1987, 1993, 1999 and most recently in 2005.',
#  "But has successfully found a strong cult audience in the US, Canada, Germany, Belgium, Switzerland and Denmark where it's widely distributed on DVD.",
#  "Nyna blamed herself for Hardin's fall to darkness.",
#  "Just after the Volhynian campaign, they allied with the Livonian Order invaded Lengvenis' estate( believed to be in Nalšia, northeastern Lithuania with the center in Ginučiai Hillfort).",
#  'It serves Durg, Bhilai and the adjoining areas of Durg district.',
#  'It was located in the province of Ontario.',
#  'This offer was generated from His Holiness Huzoor Hafiz- e- Millat.',
#  'Kitty is informed that Cormac had called Ben to help him with a werewolf hunt.',
#  'General and in that capacity had charge of the organization and dispatch to France of all American railway forces and supplies.',
#  "In 1935 he was made a member of Rome's Accademia di San Luca.",
#  'Richards was awarded the Military Cross for bravery.',
#  'It was captured by the Germans on July 16, 1941.',
#  "Telling the audience that You ai n't seen nothing yet.",
#  'He sank one ship, heavily damaged the other two, and pounded shore guns.',
#  'He threw and batted right- handed, stood tall and weighed.',
#  'He abolished Long Chamber, Montem and the Christopher.',
#  'On the morning train one day he fell into conversation with a girl whom he had seen in church at Twickenham and who was working at a firm of estate agents in Piccadilly.',
#  'Expression of LAT inhibits expressions of ICP0 via an antisense RNA mechanism.',
#  'She first gained notice as the moderator at a Law Journal panel about citing electric generators in New York City under New York energy law.',
#  'She first gained notice as the moderator at a Law Journal panel about citing electric generators in New York City under New York energy law.',
#  'In the early 1960s, he majored in music at the Carnegie Institute of Technology.',
#  "He also led design of the 201's larger cousins, the 231, 252 and 301.",
#  "Moreno performed in at least four premieres of Henley's plays.",
#  'It had a Floyd Rose floating bridge and a Bill Lawrence L90 pickup.',
#  'Stone, then assistant coach to Smith, was appointed to the position of coach for the remainder of the season.',
#  'He won the silver medal at the Junior Grand Prix in France and placed 6th in his second JGP event in Japan.',
#  'McGee recorded 11- of- 17 passes for 111 yards and a quarterback rating of 102.8.',
#  'In 1992 she recorded a solo album, Eat Life, that was not released June 23rd, 2009.',
#  'The Medical Department of the army mobilized 151 staff and regimental units.',
#  'Though it rebuilt, Ventspils did not reach its former level of prosperity while a part of the First Latvian Republic( 1918- 1940).',
#  'In June 1940, along with the Émile- Bertin, she departed from Brest with a cargo of gold from the Bank of France.',
#  "Emperor Jing of Han established an administration in Dangyang on an area of 2000 square km. In 1988 the State Council of the People's Republic of China elevated this from a county to a municipality.",
#  'Such a structure would have authority from God, ordinances such as baptism, and ordained clergy.',
#  'When Parliament resumed in January 2009, Duncan sat as a member of the Standing Committee on Environment and Sustainable Development.',
#  'However, it takes a dark turn when Ryu releases the power of Dark Hadou.',
#  "In May 1971, a team of Children's Hospital scientists led by Rigler sought and obtained a three- year grant from the NIMH to study Genie.",
#  "Scores of buyers, sellers, traders and brokers swarming around the village and the farmers' fields.",
#  'Yet the area thrives as never before, more shops and restaurants opening every month.',
#  'After his departure, Australia struggled, winning only one Test series in four years.',
#  'The body will switch back to glycolysis after a carbohydrate- rich meal.',
#  'Benfica reached two European Cup finals in 1988 and 1990, but lost to PSV and Milan respectively.',
#  'She sometimes sneaks in his bed to watch him when he sleeps.',
#  'However, Castelnuovo eventually fell into Ottoman hands and almost all the Spanish defenders, including Sarmiento, were killed.',
#  'We spent much time drinking beer obsessively.',
#  'Having seen this, Wolfe later confronts her about being an addict, though she swears she is fine.',
#  'He also transplantes his Rinnegan into Nagato to be preserved for his eventual revival years later.',
#  "KLDT also adopted a logo much similar to KNWS- TV's current logo.",
#  'Published in 1960( re-issued as Guyana Boy by Peepal Tree Press in 2002), this was the first novel by a Guyanese of Indian descent.',
#  "It is named after Geraud Duroc, Duke of Friuli( 1772- 1813), who was one of Napoleon Bonaparte's Generals.",
#  "The acoustic version, a duet with Anneke van Giersbergen performed live on Giel Beelen's 3FM radio show created a small internet hype.",
#  'MNNIT requesting Internet Protocol parameters, such as an IP address from a network server.',
#  "This includes Autechre's first EP, Cavity Job, presented for the first time on CD.",
#  'Once the counter reaches 0, the game is over.',
#  'Guessing right won the category, guessing wrong lost it.',
#  'The club facilities include treatment rooms, a swimming pool, relaxation areas, a restaurant and bar bistro, a library and lounge.',
#  'They also had to be acoustic as the actors would sing through them.',
#  'This usually includes three weeks of drive- time interviews with experts in and survivors of domestic abuse, street violence, and systemic violence.',
#  'Modern UF insulation with updated catalysts and foaming technology have reduced shrinkage to minimal levels( between 2- 4%).',
#  'In 2008, Tucker became Speaker of the state House.',
#  "The title was changed to' Thriller' after Michael told Temperton he wanted something that would appeal to kids.",
#  'They announced the release of Octopus in a high profile publicity campaign.',
#  'He was bred in County Dublin, Ireland by Larry King, a local farmer who trained and rode his own horses.',
#  'It is the farthest downstream dam on the Meadow Valley Wash.',
#  'This is derived from onomatopoeia, which is used in philology and literature and in the explanation of the origin of words in dictionaries.',
#  'It numbers 65 real estate offices and 2,500 REALTORS ® operating in Minnesota, North Dakota and western Wisconsin.',
#  'Encouraged by Edison, Ford designed and built a second vehicle, completing it in 1898.',
#  'Baur was called up to the Imperial German Army in 1915, and trained in field artillery at the airfield in Augsburg.',
#  'Dillon played his college career at Ventura College for his freshman and sophomore year, before transferring to Washington State University for junior and senior years.',
#  'He served as New York Attorney General and as a justice of the New York Supreme Court.',
#  'He graduated from Gustavus Adolphus College, St. Peter, Minnesota in 1939.',
#  'She is noted for possessing a wide vocal range of approximately four octaves.',
#  'She trained at the Lithuanian Academy of Music.',
#  'In 2009 he made a return to International Handball with four appearances for Australia at the Croatia 2009, where he was also the assistant coach of the team.',
#  'His opponent is Toni Gilhooley( R), a retired PA State Trooper who served for 25 years.',
#  'The abbey is dedicated to Our Lady of the Hermits, the title being derived from the circumstances of its foundation, from which the name Einsiedeln is also said to have originated.',
#  'He found that facial muscular movements that created facial expressions could be reliable identified through empirical research.',
#  'Along with the other people who live on the street, she is hated by the other children in school.',
#  'In a few cantons, a second round of the elections to the Council of States will be held on 11 November, 18 November, or 25 November 2007.',
#  'It has been suggested that Robert Johnson may have begun developing his version as early as 1933.',
#  "The highest peak is Gunung' Tanpa Nama'( 3,476 m) and the second highest peak in Sumatra.",
#  'Elias was born sometime in 1896 in Yekaterinsolav, a small village in the Ukraine, which has now morphed into the industrial city of Dnepropetrovsk, with over a million inhabitants.',
#  'A daughter of the Bulgarian folk singer Toni Toneff, she was born in Oslo and grew up in Lambertseter and Kolbotn.',
#  'He was placed as a pupil with William Woollett.',
#  ...]

# %%
df = pd.DataFrame(columns=["sentence"], data=simple_sentences)
df.head()
# Out:
#                                             sentence
# 0  It tells the story of the making of Bandolier ...
# 1  Under his conditions it produces pitchers that...
# 2  Given that they're pulling out all the stops, ...
# 3  It was their second EP and, like their first E...
# 4  Contains a detailed monograph on Schisandra ch...

# %%
df.to_csv("data/wiki.csv", index=False)
